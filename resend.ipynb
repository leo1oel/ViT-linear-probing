# %%
import resend

resend.api_key = "re_5vJvwxoD_6zZbatu53KxoeEKVKDPseDsk"

r = resend.Emails.send({
  "from": "onboarding@resend.dev",
  "to": "liuym13579@gmail.com",
  "subject": "Hello World",
  "html": "<p>Congrats on sending your <strong>first email</strong>!</p>"
})
